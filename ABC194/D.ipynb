# %%
import math
from scipy.special import comb

# %%
N = int(input())
# Out:
#  3

# %%
ans = 0
for i in range(10**5):
    ans += i * (1.0/N)**i
print (ans)
# Out:
# 0.7499999999999998

# %%
ans = 0

for i in range(N-1, 100):
    ans += (i * math.factorial(N-1) / N**(i-1) * comb(N, 2, exact=True))
    print (i, ans)
print (ans)
# Out:
# 2 4.0
# 3 6.0
# 4 6.888888888888889
# 5 7.2592592592592595
# 6 7.407407407407407
# 7 7.465020576131687
# 8 7.486968449931413
# 9 7.49519890260631
# 10 7.498247218411827
# 11 7.4993649342071835
# 12 7.499771376314586
# 13 7.499918147075592
# 14 7.49997083401544
# 15 7.499989650779671
# 16 7.4999963411847315
# 17 7.49999871070319
# 18 7.4999995470038225
# 19 7.499999841257749
# 20 7.49999994450474
# 21 7.499999980641187
# 22 7.499999993260263
# 23 7.49999999765782
# 24 7.499999999187406
# 25 7.499999999718511
# 26 7.499999999902628
# 27 7.499999999966361
# 28 7.499999999988392
# 29 7.499999999995999
# 30 7.4999999999986215
# 31 7.499999999999525
# 32 7.499999999999836
# 33 7.499999999999942
# 34 7.499999999999979
# 35 7.499999999999991
# 36 7.499999999999996
# 37 7.499999999999997
# 38 7.499999999999998
# 39 7.499999999999998
# 40 7.499999999999998
# 41 7.499999999999998
# 42 7.499999999999998
# 43 7.499999999999998
# 44 7.499999999999998
# 45 7.499999999999998
# 46 7.499999999999998
# ...

# %%
N = 3
i = N-1
a = i * math.factorial(N-1) / N**(i-1) * comb(N, 2, exact=True)
print (a)
# Out:
# 4.0
