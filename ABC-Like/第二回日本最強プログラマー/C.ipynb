# %%
A, B = map(int, input().split())
ans = 1
for gcd in range(1, A+1):
    cnt = B//gcd - (A-1)//gcd
    print (gcd, cnt)
    if cnt >= 2:
        ans = gcd
print (ans)
# Out:
#  101 137
# 1 37
# 2 18
# 3 12
# 4 9
# 5 7
# 6 6
# 7 5
# 8 5
# 9 4
# 10 3
# 11 3
# 12 3
# 13 3
# 14 2
# 15 3
# 16 2
# 17 3
# 18 2
# 19 2
# 20 1
# 21 2
# 22 2
# 23 1
# 24 1
# 25 1
# 26 2
# 27 2
# 28 1
# 29 1
# 30 1
# 31 1
# 32 1
# 33 1
# 34 2
# 35 1
# 36 1
# 37 1
# 38 1
# 39 1
# 40 1
# 41 1
# 42 1
# 43 1
# 44 1
# 45 1
# 46 0
# 47 0
# 48 0
# 49 0
# 50 0
# 51 1
# 52 1
# 53 1
# 54 1
# 55 1
# 56 1
# 57 1
# 58 1
# 59 1
# 60 1
# 61 1
# 62 1
# 63 1
# 64 1
# 65 1
# 66 1
# 67 1
# 68 1
# 69 0
# 70 0
# 71 0
# 72 0
# 73 0
# 74 0
# 75 0
# 76 0
# 77 0
# 78 0
# 79 0
# 80 0
# 81 0
# 82 0
# 83 0
# 84 0
# 85 0
# 86 0
# 87 0
# 88 0
# 89 0
# 90 0
# 91 0
# 92 0
# 93 0
# 94 0
# 95 0
# 96 0
# 97 0
# 98 0
# 99 0
# 100 0
# 101 1
# 34
